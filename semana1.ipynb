# %% [markdown]
# #Sesion1
# Este archivo es para dos cosas
# 1.familianizarnos con jupyternotebook
# 2. practicar phyton

# %%
print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# Variables
# Las variables en Python son tipos de datos que tienen diferente forma
# . Numericas
#    .Enteros
#    .Flotante
# .cadena de caracteres
# .Booleanos
# .Compuestos

# %%
nombre = "Jose"
edad = 18
es_estudiante= True
esta_activo= None
print(type (nombre))
print(type (edad))
print(type(es_estudiante))
print(type(esta_activo))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'NoneType'>

# %%
nombre = "Jose"
edad = 18
print("hola", nombre , "ya vi que tienes", edad , "años de edad")
# Out:
# hola Jose ya vi que tienes 18 años de edad

# %% [markdown]
# ALgoritmo para calcular velocidad

# %%
distancia = int (input("ingrese la velocidad en kilometros:"))
tiempo= int (input ("ingrese el tiempo en horas"))
print ("El dato distancia es de tipo:", type(distancia))
print("El dato tiempo es de tipo: ", type(tiempo))
velocidad = distancia / tiempo
print ("la velocidad promedio es: ", velocidad)
# Out:
# El dato distancia es de tipo: <class 'int'>
# El dato tiempo es de tipo:  <class 'int'>
# la velocidad promedio es:  0.75

# %% [markdown]
# Entradas y salidas

# %%
nombre = input("pon tu nombre porfa :")
edad = input ("pon tu edad porfa: ")
print ("hola", nombre , "tienes" , edad , "años")
# Out:
# hola Jose tienes 18 años
