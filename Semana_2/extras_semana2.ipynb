# %% [markdown]
# Extra 1: Control de aforo con break y continue (while)

# %%
total = 0

while True:
    costo = float(input("Ingresa el costo del boleto: "))

    if costo == 0:
        print("Menor de 3 años, sin cargo")
        continue

    total = total + costo

    if total >= 100:
        print("Aforo alcanzado, se detiene el registro")
        break

print(f"Total acumulado: ${total:.2f}")
# Out:
# Menor de 3 años, sin cargo
# Aforo alcanzado, se detiene el registro
# Total acumulado: $100.00

# %% [markdown]
# Extra 2: Estadística de visitantes con for

# %%
Visitantes = int(input("¿Cuantos visitantes son?"))

adultos = 0
edad_acumulada = 0

for v in range(1, Visitantes+ 1):
    edad = int(input(f"Edad del visitante {v}: "))

    edad_acumulada = edad_acumulada + edad

    if edad >= 18:
        adultos = adultos + 1

Promedio_de_edad = edad_acumulada / Visitantes
print(f"Numero de visitantes : {Visitantes}")
print(f"Adultos: {adultos}")
print(f"Promedio de edad: {Promedio_de_edad:.0f}")
# Out:
# Numero de visitantes : 2
# Adultos: 1
# Promedio de edad: 16

# %% [markdown]
# Extra 3: Depuración de un cobro con PDB

# %%
precio = 45
descuento = 0.12
monto_del_descuento = precio * descuento
total= precio-monto_del_descuento
print(f"Total: ${total:.2f}")
# Out:
# Total: $39.60

# %% [markdown]
# Extra 4: Pirámide de asteriscos con for

# %%
Altura_piramide = int(input("¿Cual es la altura?"))

for i in range(1, Altura_piramide +1 ):
    print("*" * i)
# Out:
# *
# **
# ***
# ****
